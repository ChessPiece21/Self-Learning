# %% [markdown]
# # Exercise: Data Cleaning
# This lesson will help you practice the skills required for editing parts of a dataset using Pandas.
#
# The dataset that we're working with in this lesson is still the one from Hannah Andersen and Matt Daniels's *Pudding* essay, ["Film Dialogue from 2,000 screenplays, Broken Down by Gender and Age"](https://pudding.cool/2017/03/film-dialogue/). You can find the dataset's documentation [here](https://docs.google.com/document/d/1EMsuxPrX4ChO2HSMy_zKidS-KQluoIfcv0_23W5BKuA/edit?usp=sharing).

# %% [markdown]
# To begin, just import Pandas again, and change its display settings, and import the same *Pudding* data frame/CSV.

# %%
# Import Pandas
import pandas as pd
pd.options.display.max_rows = 100

# Get the data, using the same method from the last lesson.
pudding_df = pd.read_csv("Pudding-Film-Dialogue.csv")

# %% [markdown]
# ## Data Frame Heads:
# The **.head()** method in Pandas can show you the first few in a set amount of rows in the data frame, printing them after you specify the parameter in the parentheses. Try it out!

# %%
pudding_df.head(10)
# Out:
#                            title  release_year        character gender  words  \
# 0  The Bridges of Madison County          1995            Betty  woman    311
# 1  The Bridges of Madison County          1995  Carolyn Johnson  woman    873
# 2  The Bridges of Madison County          1995          Eleanor  woman    138
# 3  The Bridges of Madison County          1995  Francesca Johns  woman   2251
# 4  The Bridges of Madison County          1995            Madge  woman    190
# 5  The Bridges of Madison County          1995  Michael Johnson    man    723
# 6  The Bridges of Madison County          1995   Robert Kincaid    man   1908
# 7                     15 Minutes          2001     Bobby Korfin    man    328
# 8                     15 Minutes          2001  Daphne Handlova  woman    409
# 9                     15 Minutes          2001  Deputy Chief Fi    man    347
#
#    proportion_of_dialogue   age  gross  script_id
# 0                0.048639  35.0  142.0        280
# 1                0.136534   NaN  142.0        280
# 2                0.021583   NaN  142.0        280
# 3                0.352049  46.0  142.0        280
# 4                0.029715  46.0  142.0        280
# 5                0.113075  38.0  142.0        280
# 6                0.298405  65.0  142.0        280
# 7                0.036012   NaN   37.0        623
# 8                0.044906  28.0   37.0        623
# 9                0.038098   NaN   37.0        623

# %% [markdown]
# ## Investigating a Data Frame
# The **.info()** method can help you understand the columns in the data, such as their data types, by printing a list of its information.

# %%
pudding_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23047 entries, 0 to 23046
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   title                   23047 non-null  object
#  1   release_year            23047 non-null  int64
#  2   character               23047 non-null  object
#  3   gender                  23047 non-null  object
#  4   words                   23047 non-null  int64
#  5   proportion_of_dialogue  23047 non-null  float64
#  6   age                     18262 non-null  float64
#  7   gross                   19386 non-null  float64
#  8   script_id               23047 non-null  int64
# dtypes: float64(3), int64(3), object(3)
# memory usage: 1.6+ MB

# %% [markdown]
# Just like Python has different data types, Pandas has different data types, too. These data types are automatically assigned to columns when we read in a CSV file. We can check these Pandas data types with the **.dtypes** method.

# %% [markdown]
# ## Checking for Duplicates
# We can check for duplicates in the data frame using the **.duplicated()** method and setting the parameter **keep=False**, which displays the duplicated values and removes them.
#
# You can use this to isolate only the rows in the dataframe that are exact duplicates.

# %%
pudding_filter = pudding_df.duplicated(keep=False)
pudding_filter
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 23042    False
# 23043    False
# 23044    False
# 23045    False
# 23046    False
# Length: 23047, dtype: bool

# %% [markdown]
# The output above is reporting whether each row in the dataset is a duplicate. You can also use this inside a filter to isolate the exact duplicates.

# %% [markdown]
# ## Cleaning Data with String Methods
# Pandas has some special [string methods](https://pandas.pydata.org/pandas-docs/stable/user_guide/text.html#string-methods) similar to the base Python ones, but they will transform every single string value in a column, and you have to add **.str** to the method chain.
#
# Here are some of these methods:
# - **.str.lower()** makes each row lowercase, and **.str.upper()** makes each row uppercase. Similarly, **.str.title()** makes every row titlecase.
# - **.str.replace('old string', 'new string')** replaces the value of one old string with a new string for each row.
# - **.str.contains('some string')** tests whether each row contains a specific string value.
# - **.str.split('delimiter')** returns a list of substrings separated by a given delimiter, while the opposite, **.str.join()** returns a list of substrings in a given list together using some string.
#
# To change character names in the columns to lowercase and uppercase, you can use **.str.upper()** and **.str.lower()**. Try it out here!

# %%
upper_pudding_df = pudding_df["character"].str.upper()
upper_pudding_df.sample(10)
# Out:
# 4528          TOM KRUGER
# 3787              GRANNY
# 23034         THE FATHER
# 21185     CONSTANCE SACK
# 3030     DEXTER JETTSTER
# 11292              CHUCK
# 12360              DAVEY
# 5780         BLACK SHAWL
# 9398        FRANK CATTON
# 15809        KING ROLAND
# Name: character, dtype: object

# %%
lower_pudding_df = pudding_df["character"].str.lower()
lower_pudding_df.sample(10)
# Out:
# 18959         mr. thomas
# 16049               sage
# 12025              trudy
# 7161               maria
# 13603              woman
# 506              sattler
# 20580              kathy
# 2634     general francis
# 2959     gregory       (
# 9076          mrs. grant
# Name: character, dtype: object

# %% [markdown]
# If you want to replace the gender columns' single letter abbreviations for "man"/"woman" (gender) with "male"/"female" (gender identity), you can use the **.str.replace()** method.

# %%
pudding_df["gender"] = pudding_df["gender"].str.replace("man", "male")
pudding_df["gender"] = pudding_df["gender"].str.replace("wo", "fe") # There's this weird error that came up changing ALL instances of "male," but this is how I was able to fix it.
# View the cleaned dataset:
pudding_df.sample(10)
# Out:
#                           title  release_year        character  gender  words  \
# 3811                 Affliction          1997      Jack Hewitt    male   1616
# 15713     Come See the Paradise          1990  Dulcie Kawamura    male    365
# 15121  Star Trek: First Contact          1996             Ruby  female    470
# 8482         Living in Oblivion          1995            Wanda  female   3178
# 10047                 Rush Hour          1998          Johnson  female    467
# 2242       Natural Born Killers          1994       Wayne Gale    male   4624
# 15240            Sweet November          2001            Abner    male    303
# 4715                  The Birds          1963  Deputy Al Malon    male    660
# 17201                     Ouija          2014     Mrs. Galardi  female    167
# 20877     Gone in Sixty Seconds          2000             Toby    male    525
#
#        proportion_of_dialogue   age  gross  script_id
# 3811                 0.081616  31.0   11.0       1559
# 15713                0.051605   NaN    1.0       5298
# 15121                0.070328   NaN  181.0       5036
# 8482                 0.146088  30.0    2.0       2787
# 10047                0.057804  39.0  261.0       3248
# 2242                 0.380513  29.0  104.0       1185
# 15240                0.034393  11.0   38.0       5086
# 4715                 0.030005  56.0    NaN       1826
# 17201                0.021799  42.0   54.0       6156
# 20877                0.051562  27.0  164.0       8050

# %% [markdown]
# We can also use **.str.contains()** to search for a particular word or phrase in a column, like *Star Wars*. Try it out here.

# 10593       3427
# 10594       3427
# 10595       3427
# 10596       3427
# 10597       3427
# 10598       3427
# 10599       3427
# 10600       3427
# 10601       3427
# 10602       3427
# 10603       3427
# 10604       3433
# 10605       3433
# 10606       3433
# 10607       3433
# 10608       3433
# 10609       3433
# 10610       3433
# 10611       3433
# 10612       3433
# 10613       3433
# 10614       3433
# 10615       3433
# 10616       3433
# 10617       3437
# 10618       3437
# 10619       3437
# 10620       3437
# 10621       3437
# 10622       3437
# 10623       3437
# 10624       3437
# 10625       3437
# 10626       3437
# 10627       3437
# 10628       3437
# 10629       3437
# 10630       3437
# 10631       3437
# 10632       3437
# 10633       3437
# 10634       3437
# 10635       3437
# 20999       8099
# 21000       8099
# 21001       8099
# 21002       8099
# 21003       8099
# 21004       8099
# 21005       8099
# 21006       8099
# 21007       8099
# 21008       8099
# 21009       8099
# 21010       8099

# %%
# Try it again with a movie you like!
pudding_df[pudding_df["title"].str.contains("Mean Girls")]
# Out:
#             title  release_year        character  gender  words  \
# 13937  Mean Girls          2004    Aaron Samuels    male    426
# 13938  Mean Girls          2004       Cady Heron  female   2798
# 13939  Mean Girls          2004           Damian    male    624
# 13940  Mean Girls          2004  Gretchen Wiener  female    609
# 13941  Mean Girls          2004        Janis Ian  female    907
# 13942  Mean Girls          2004      Karen Smith  female    301
# 13943  Mean Girls          2004       Mr. Duvall    male    365
# 13944  Mean Girls          2004      Mrs. George  female    125
# 13945  Mean Girls          2004      Ms. Norbury  female    720
# 13946  Mean Girls          2004    Regina George  female   1030
#
#        proportion_of_dialogue   age  gross  script_id
# 13937                0.053890  23.0  120.0       4605
# 13938                0.353953  18.0  120.0       4605
# 13939                0.078937  26.0  120.0       4605
# 13940                0.077040  22.0  120.0       4605
# 13941                0.114738  22.0  120.0       4605
# 13942                0.038077  19.0  120.0       4605
# 13943                0.046173  43.0  120.0       4605
# 13944                0.015813  33.0  120.0       4605
# 13945                0.091082  34.0  120.0       4605
# 13946                0.130297  26.0  120.0       4605

# %% [markdown]
# ## Applying Functions:
# With the **.apply()** method, we can run functions on every row in a Pandas column or data frame. For example, if you create a function called **make_text_titlecase()** that makes a string title-case, then you can apply it to functions using **.apply()**.
#
# Try making this, as there is no way to make text title-case using Pandas string methods.

# %%
# Define the function here:
def make_text_titlecase(text):
    titlecase_text = text.title()
    return titlecase_text

# Try it out with a sample string:
make_text_titlecase("i love tacos")
# Out:
# 'I Love Tacos'

# %% [markdown]
# Now try this out by making each name in the data frame lowercase, and then title-case!

# %%
pudding_df["character"] = pudding_df["character"].str.lower()

# Checking to make sure it worked:
pudding_df.sample(10)
# Out:
#                          title  release_year        character  gender  words  \
# 14483   The Poseidon Adventure          1972           purser    male    113
# 8428             The Lion King          1994           pumbaa    male    103
# 15246           Sweet November          2001    vince holland    male    586
# 3884           All About Steve          2009          teacher  female    183
# 19064             Ghostbusters          1984      walter peck    male    540
# 14678  The Rules of Attraction          2002         mitchell    male    281
# 17819                 Hannibal          2001       proprietor    male    161
# 18621  In the Mouth of Madness          1994  jackson harglow    male    225
# 4348         Authors Anonymous          2014      lois pepper  female    337
# 4885     Bodies, Rest & Motion          1993            carol  female   1952
#
#        proportion_of_dialogue   age  gross  script_id
# 14483                0.019188  41.0  477.0       4810
# 8428                 0.037292  45.0  880.0       2782
# 15246                0.066515  43.0   38.0       5086
# 3884                 0.011772  52.0   39.0       1603
# 19064                0.050321  37.0  592.0       7290
# 14678                0.028387  22.0    9.0       4899
# 17819                0.021162   NaN  253.0       6568
# 18621                0.044049  71.0   18.0       7102
# 4348                 0.027967  58.0    NaN       1716
# 4885                 0.151013  30.0    1.0       1870

# %%
pudding_df["character"] = pudding_df["character"].apply(make_text_titlecase)

# Checking to make sure it worked:
pudding_df.sample(10)
# Out:
#                    title  release_year        character  gender  words  \
# 13993    Michael Clayton          2007       Marty Bach    male    616
# 12381  Conspiracy Theory          1997             Flip    male    114
# 22515           Hot Fuzz          2007     Met Sergeant    male    204
# 4122       Anna Karenina          2012            Dolly  female    404
# 8184        Larry Crowne          2011           Denise  female    221
# 14393            Panther          1995          Brimmer    male    724
# 7663       The Ice Storm          1997       Wendy Hood  female   1686
# 726          City of Joy          1992  Gangooly - Con     male    581
# 8215    The Last Samurai          2003    Emperor Meiji    male    884
# 7818            Invictus          2009             Mary  female    107
#
#        proportion_of_dialogue   age  gross  script_id
# 13993                0.080042  73.0   61.0       4619
# 12381                0.013713  50.0  144.0       4039
# 22515                0.021537  36.0   29.0       8902
# 4122                 0.036841  36.0   13.0       1659
# 8184                 0.016677   NaN   39.0       2733
# 14393                0.073930  59.0   13.0       4765
# 7663                 0.082858  17.0   14.0       2591
# 726                  0.041859   NaN   30.0        809
# 8215                 0.052632  20.0  160.0       2739
# 7818                 0.014765  39.0   43.0       2632

# %% [markdown]
# ## Filtering Data Frames
# You can also use the filtering syntax from before to make only a specific category appear. Try it out with gender below.

# %%
female_df = pudding_df[pudding_df["gender"] == "female"]
female_df.sample(10)
# Out:
#                                title  release_year        character  gender  \
# 1350       Gremlins 2: The New Batch          1990    Kate Beringer  female
# 6082     The Distinguished Gentleman          1992     Miss Loretta  female
# 20967                      Spotlight          2015          Barbara  female
# 20742                        The Ref          1994         Caroline  female
# 16002              Dear White People          2014   Sofia Fletcher  female
# 19838  The Town That Dreaded Sundown          2014             Jami  female
# 9828                   Rambling Rose          1991             Doll  female
# 10650                   Storytelling          2001  Elizabeth St. C  female
# 16493                          Truth          2015       Betsy West  female
# 5270                          Casino          1995  Female Newscast  female
#
#        words  proportion_of_dialogue   age  gross  script_id
# 1350     825                0.110516  27.0   85.0        973
# 6082     110                0.073628  36.0   97.0       2160
# 20967    105                0.007465  52.0   35.0       8089
# 20742   2636                0.238920  39.0   23.0       8000
# 16002    276                0.024796  24.0    4.0       5397
# 19838   2077                0.275209  23.0    NaN       7633
# 9828     954                0.032243  13.0   12.0       3174
# 10650    144                0.011158   NaN    1.0       3455
# 16493    339                0.027904  44.0    2.0       5507
# 5270     460                0.006797   NaN   84.0       1963
